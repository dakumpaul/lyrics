# %% [markdown]
# ### 2Face Idibia: A Lyrical analysis
# This exercise will pull all the songs by 2Face Idibia on Genius.com and run sentiment analysis on the lyrics to determine the sentiment polatiry for the songs.

# %% [markdown]
# First we save our genius identification

# %%
genius_client_id = 'mM_UqRz1pNsawnzq1KJ9aSrvsz3P6wTLARQNongLrcXZpTiRA25ul_xD5gqQTSDo'
genius_secret = 'KyNJWaxnx3TSySHdnnA07E5Abw1G5X--SPz33sBJ65XdQni-UKVOYW8owdH9o2lRH7u9ykvml9_4jEghf7qnZw'
genius_token = 'W7RIDSht2rGxPSp4c6R2xwXMeEu6nWJvgedjI_a9ANczFGlkDz6JkHSfkXtsehnH'

# %% [markdown]
# Then we import the required libraries.

# %%
import lyricsgenius
import pandas as pd
import json
import nltk
import re
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %% [markdown]
# We then save the genius request

# %%
genius = lyricsgenius.Genius(genius_token)

# %% [markdown]
# Then we search the api for all songs by "2face Idibia".<br> What we found out was that the same artist is saved under different names, probably because the artist has released songs under different names, or iterations of the same name.<br>"2Face Idibia" and "2Baba".

# %%
_2Face_Idibia = genius.search_artist("2face Idibia", sort="title")
# Out:
# Searching for songs by 2face Idibia...
#
# Changing artist name to '2Face Idibia'
# Song 1: "4 Instance"
# Song 2: "African Queen"
# Song 3: "African queen (mkd remix)"
# Song 4: "Be There"
# Song 5: "Dance Floor"
# Song 6: "Dance In The Rain"
# Song 7: "Dancing in The Rain"
# Song 8: "E Be Like Say"
# Song 9: "Fly"
# Song 10: "Gaga Shuffle"
# Song 11: "Hate What You Do To Me"
# Song 12: "Higher Healing"
# Song 13: "Higher (Spiritual Healing)"
# Song 14: "If Love Is A Crime"
# Song 15: "Implication"
# Song 16: "Implications"
# Song 17: "I sing"
# Song 18: "My Love"
# Song 19: "Nfana Ibaga"
# Song 20: "Nfana Ibaga (No Problem) (Remix)"
# Song 21: "No shakin"
# Song 22: "Ocho"
# Song 23: "Ole"
# Song 24: "Olè ft Freestyle"
# Song 25: "Ole (Thief)"
# Song 26: "Omo tosan"
# Song 27: "One Love"
# Song 28: "Only Me"
# Song 29: "Outside"
# Song 30: "Oya come make we go"
# Song 31: "Rainbow"
# Song 32: "Raindrops"
# Song 33: "Right Here"
# Song 34: "See Me So"
# Song 35: "Thank U Lord"
# Song 36: "True Love"
# Song 37: "U No Holy Pass"
# Done. Found 37 songs.

# %%
len(_2Face_Idibia)
# Out:
# 37

# %% [markdown]
# So 37 songs were found under "2Face Idibia". This should be enough for now.<br>We can also search for 2Baba to see what comes up.

# %%
_2Baba = genius.search_artist("2baba",sort="title")
# Out:
# Searching for songs by 2baba...
#
# Changing artist name to '2Baba'
# Song 1: "2Baba ft Wizkid -Opo (lyrics )"
# Song 2: "Amaka"
# Song 3: "Holy Holy"
# Song 4: "Officially Blind (Remix)"
# Song 5: "Oyi"
# Song 6: "Target You"
# Done. Found 6 songs.

# %% [markdown]
# The next line saves the information we retrieved for 2Face Idibia as a json file in the current working directory.

# %%
_2Face_Idibia.save_lyrics()
# Out:
# Wrote `Lyrics_2FaceIdibia.json`

# %% [markdown]
# We will then import that json file and load into "Artist"

# %%
with open('Lyrics_2FaceIdibia.json') as json_file:
    Artist = json.load(json_file)

# %% [markdown]
# We will now look at the keys available in the json file. This will enable us understand the structure of the file a bit better.

# %%
Artist.keys()
# Out:
# dict_keys(['alternate_names', 'api_path', 'description', 'facebook_name', 'followers_count', 'header_image_url', 'id', 'image_url', 'instagram_name', 'is_meme_verified', 'is_verified', 'name', 'translation_artist', 'twitter_name', 'url', 'current_user_metadata', 'description_annotation', 'user', 'songs'])

# %% [markdown]
# The first thing that stands out is the 'songs' key. After some trial and error we have figured out how to access the songs and their lyrics.<br>We now create a dictionary that holds each song as key and the lyrics as values.

# %%
lyrics = {}
for x in range(len(Artist["songs"])):
    lyrics[Artist["songs"][x]["title"]] = Artist["songs"][x]["lyrics"]

# %%
lyrics.keys()
# Out:
# dict_keys(['4 Instance', 'African Queen', 'African queen (mkd remix)', 'Be There', 'Dance Floor', 'Dance In The Rain', 'Dancing in The Rain', 'E Be Like Say', 'Fly', 'Gaga Shuffle', 'Hate What You Do To Me', 'Higher Healing', 'Higher (Spiritual Healing)', 'If Love Is A Crime', 'Implication', 'Implications', 'I sing', 'My Love', 'Nfana Ibaga', 'Nfana Ibaga (No Problem) (Remix)', 'No shakin', 'Ocho', 'Ole', 'Olè ft Freestyle', 'Ole (Thief)', 'Omo tosan', 'One Love', 'Only Me', 'Outside', 'Oya come make we go', 'Rainbow', 'Raindrops', 'Right Here', 'See Me So', 'Thank U Lord', 'True Love', 'U No Holy Pass'])

# %% [markdown]
# The dictionary 'lyrics' holds each song as key and the lyrics as values.<br><br>We'll now create a word cloud of the lyrics for one of the songs.

# %%
wordcloud = WordCloud(width=480, height=480, margin=0).generate(lyrics['Hate What You Do To Me'])
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 

plt.show()

# %% [markdown]
# Finally we will use the NaiveBayesAnalyzer from the textblob.sentiments package to compute the sentiment polarity of each song.

# %%
lyrics_songlist = [] #List of all the songs and their lyrics.
for song in lyrics:
    temp = [song, lyrics[song]]
    lyrics_songlist.append(temp)

# %%
import pandas as pd
import csv
from textblob import TextBlob
from textblob.sentiments import NaiveBayesAnalyzer

x = 0
with open('tuface_scores.csv','w') as f1:
    writer=csv.writer(f1, delimiter=',',lineterminator='\n',)
    for song in lyrics:
        sent = TextBlob(lyrics[song])
        row = (lyrics_songlist[x][0], round(sent.sentiment.polarity,3))
        #row = [i + j*0.2 for j in range(i+1)]
        x = x+1
        writer.writerow(row)

# %%
data = pd.read_csv("tuface_scores.csv",names = ['Song', 'Score'], encoding='latin-1')
data
# Out:
#                                 Song  Score
# 0                         4 Instance  0.082
# 1                      African Queen  0.274
# 2          African queen (mkd remix)  0.248
# 3                           Be There  0.209
# 4                        Dance Floor  0.377
# 5                  Dance In The Rain  0.217
# 6                Dancing in The Rain  0.217
# 7                      E Be Like Say  0.010
# 8                                Fly  0.368
# 9                       Gaga Shuffle  0.153
# 10            Hate What You Do To Me -0.406
# 11                    Higher Healing  0.037
# 12        Higher (Spiritual Healing)  0.217
# 13                If Love Is A Crime  0.412
# 14                       Implication  0.000
# 15                      Implications  0.000
# 16                            I sing  0.004
# 17                           My Love  0.324
# 18                       Nfana Ibaga  0.221
# 19  Nfana Ibaga (No Problem) (Remix)  0.085
# 20                         No shakin  0.060
# 21                              Ocho  0.331
# 22                               Ole  0.149
# 23                  Olè ft Freestyle  0.197
# 24                       Ole (Thief)  0.180
# 25                         Omo tosan  0.465
# 26                          One Love  0.130
# 27                           Only Me  0.206
# 28                           Outside  0.286
# 29               Oya come make we go  0.107
# 30                           Rainbow  0.000
# 31                         Raindrops -0.013
# 32                        Right Here  0.199
# 33                         See Me So  0.220
# 34                      Thank U Lord  0.377
# 35                         True Love  0.390
# 36                    U No Holy Pass  0.086

# %%
import matplotlib.pyplot as plt
data.sort_values('Score', ascending = True, inplace= True)
data.plot(kind='bar',x='Song',y='Score',color='blue')
plt.rcParams['figure.figsize'] = [17, 10]
plt.grid(b=None, which='major', axis='both')
plt.show()
